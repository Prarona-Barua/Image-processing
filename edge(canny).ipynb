# %% [markdown]
# <a href="https://colab.research.google.com/github/Prarona-Barua/Image-processing/blob/main/edge(canny).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt



dataset_folder = '/content/drive/MyDrive/flower'

for filename in os.listdir(dataset_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(dataset_folder, filename)
        image = cv2.imread(image_path)
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        edges = cv2.Canny(gray_image, threshold1=30, threshold2=100)

        # Display the original and edge-detected images
        fig, ax = plt.subplots(1, 2, figsize=(10, 5))
        ax[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        ax[0].set_title('Original Image')
        ax[0].axis('off')
        ax[1].imshow(edges, cmap='gray')
        ax[1].set_title('Edge Detection')
        ax[1].axis('off')
        plt.show()
