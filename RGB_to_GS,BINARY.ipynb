# %% [markdown]
# <a href="https://colab.research.google.com/github/Prarona-Barua/Image-processing/blob/main/RGB_to_GS%2CBINARY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

#read the image 
image = cv2.imread('/content/drive/MyDrive/cat.jpg')

#Convert to grayscale
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
_, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

#display grayscale images
cv2_imshow(color_image)
cv2_imshow(image)
cv2_imshow(binary_image)
# Out:
# <PIL.Image.Image image mode=RGB size=735x469 at 0x7FE40CE1F700>
# <PIL.Image.Image image mode=RGB size=735x469 at 0x7FE40CE1EF20>
# <PIL.Image.Image image mode=RGB size=735x469 at 0x7FE40CE1F700>

# %%
import matplotlib.pyplot as plt
histogram = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.plot(histogram)
plt.title('Grayscale Image Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
histogram = cv2.calcHist([binary_image], [0], None, [256], [0, 256])
plt.plot(histogram)
plt.title('Binary Image Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
histogram = cv2.calcHist([color_image], [0], None, [256], [0, 256])
plt.plot(histogram)
plt.title('Color Image Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()
