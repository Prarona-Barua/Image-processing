# %% [markdown]
# <a href="https://colab.research.google.com/github/Prarona-Barua/Image-processing/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt
import cv2


folder_path = '/content/drive/MyDrive/cartoons'


image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith(('.png', '.jpg', '.jpeg'))]


for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    image = cv2.imread(image_path, 0)  


    hist = cv2.calcHist([image], [0], None, [256], [0, 256])


    plt.figure()
    plt.title('Histogram - {}'.format(image_file))
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.plot(hist)
    plt.xlim([0, 256])
    plt.show()
